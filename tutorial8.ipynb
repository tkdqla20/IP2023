# %% [markdown]
# 좌표 찾아주는 코드

# %%
import cv2
import numpy as np
import random

# Create a black image
img = np.zeros((512,512,3), np.uint8)

# Mouse callback function
def draw_circle(event, x, y, flags, param):
    # Generate a random radius between 10 and 100
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img, (x, y), 30, (random.randrange(0,255),random.randrange(0,255),random.randrange(0,255)), 3)
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(img,'mouse-('+str(x)+','+str(y)+')', (10,40), font, 1, (255,255,255), 2, cv2.LINE_AA)

# Create a window and bind the function to the window
cv2.namedWindow('image')
cv2.setMouseCallback('image', draw_circle)

while True:
    cv2.imshow('image', img)
    if cv2.waitKey(20) & 0xFF == 27:  # Press 'Esc' key to exit
        break

cv2.destroyAllWindows()

# %% [markdown]
# 원과 텍스트 리셋

# %%
import cv2
import numpy as np
import random

# Create a black image
img = np.zeros((512,512,3), np.uint8)

# Mouse callback function
def draw_circle(event, x, y, flags, param):
    # Generate a random radius between 10 and 100
    global img
    if event == cv2.EVENT_LBUTTONDOWN:
        img = np.zeros((512,512,3), np.uint8)
        cv2.circle(img, (x, y), 30, (random.randrange(0,255),random.randrange(0,255),random.randrange(0,255)), 3)
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(img,'mouse-('+str(x)+','+str(y)+')', (10,40), font, 1, (255,255,255), 2, cv2.LINE_AA)

# Create a window and bind the function to the window
cv2.namedWindow('image')
cv2.setMouseCallback('image', draw_circle)

while True:
    cv2.imshow('image', img)
    if cv2.waitKey(20) & 0xFF == 27:  # Press 'Esc' key to exit
        break

cv2.destroyAllWindows()

# %% [markdown]
# 도형 추가?

# %%
import cv2
import numpy as np
import random

# Create a black image
img = np.zeros((512,512,3), np.uint8)

# Mouse callback function
def draw_circle(event, x, y, flags, param):
    # Generate a random radius between 10 and 100
    global img
    if event == cv2.EVENT_LBUTTONDOWN:
        img = np.zeros((512,512,3), np.uint8)
        img[:100,:,2]=255
        img[100:200,:,1]=255
        cv2.circle(img, (x, y), 30, (random.randrange(0,255),random.randrange(0,255),random.randrange(0,255)), 3)
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(img,'mouse-('+str(x)+','+str(y)+')', (10,40), font, 1, (255,255,255), 2, cv2.LINE_AA)

# Create a window and bind the function to the window
cv2.namedWindow('image')
cv2.setMouseCallback('image', draw_circle)

while True:
    cv2.imshow('image', img)
    if cv2.waitKey(20) & 0xFF == 27:  # Press 'Esc' key to exit
        break

cv2.destroyAllWindows()

# %% [markdown]
# 맨 위에 무슨 도형 추가

# %%
import cv2
import numpy as np
import random

# Create a black image
img = np.zeros((512,512,3), np.uint8)

# Mouse callback function
def draw_circle(event, x, y, flags, param):
    # Generate a random radius between 10 and 100
    global img
    if event == cv2.EVENT_LBUTTONDOWN:

        img[:50,:,:]=20
        cv2.circle(img, (x, y), 30, (random.randrange(0,255),random.randrange(0,255),random.randrange(0,255)), 3)
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(img,'mouse-('+str(x)+','+str(y)+')', (10,40), font, 1, (255,255,255), 2, cv2.LINE_AA)

# Create a window and bind the function to the window
cv2.namedWindow('image')
cv2.setMouseCallback('image', draw_circle)

while True:
    cv2.imshow('image', img)
    if cv2.waitKey(20) & 0xFF == 27:  # Press 'Esc' key to exit
        break

cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

def nothing(x):
    pass

img = np.zeros((300, 512, 3), np.uint8)
cv2.namedWindow('image')

cv2.createTrackbar('R', 'image', 0, 255, nothing)
cv2.createTrackbar('G', 'image', 0, 255, nothing)
cv2.createTrackbar('B', 'image', 0, 255, nothing)

switch = '0 : OFF \n1 : ON'
cv2.createTrackbar(switch, 'image', 0, 1, nothing)

while True:
    cv2.imshow('image', img)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break

    r = cv2.getTrackbarPos('R', 'image')
    g = cv2.getTrackbarPos('G', 'image')
    b = cv2.getTrackbarPos('B', 'image')
    s = cv2.getTrackbarPos(switch, 'image')

    if s == 0:
        img[:] = 0
    else:
        img[:] = [b, g, r]

cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

def nothing(x):
    pass

# Load the image
img = cv2.imread('image.jpg')

# Create a black image for the controls
controls_img = np.zeros((300, 512, 3), np.uint8)
cv2.namedWindow('image')

cv2.createTrackbar('R', 'image', 0, 255, nothing)
cv2.createTrackbar('G', 'image', 0, 255, nothing)
cv2.createTrackbar('B', 'image', 0, 255, nothing)

switch = '0 : OFF \n1 : ON'
cv2.createTrackbar(switch, 'image', 0, 1, nothing)

while True:
    cv2.imshow('image', img)
    cv2.imshow('controls', controls_img)  # Show the controls image

    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break

    r = cv2.getTrackbarPos('R', 'image')
    g = cv2.getTrackbarPos('G', 'image')
    b = cv2.getTrackbarPos('B', 'image')
    s = cv2.getTrackbarPos(switch, 'image')

    if s == 0:
        img[:] = 0
    else:
        img[:] = [b, g, r]

cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

start_x, start_y, end_x, end_y = -1, -1, -1, -1
drawing = False

def draw_rectangle(event,x,y,flags,param):
    global start_x,start_y,end_x,end_y,drawing,img

    if event == cv2.EVENT_LBUTTONDOWN:
        drawing=True
        start_x,start_y=x,y

    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing:
            end_x,end_y=x,y
            img_temp=img.copy()
            overlay = np.full_like(img_temp,(0 ,0 ,150))
            cv2.addWeighted(overlay[start_y:end_y+1,start_x:end_x+1], 0.5,img_temp[start_y:end_y+1,start_x:end_x+1], 0.5 , 0,img_temp[start_y:end_y+1,start_x:end_x+1])
            cv2.imshow('Everest Image', img_temp)

    elif event == cv2.EVENT_LBUTTONUP:
        drawing=False
        
         # Display coordinates.
        font=cv2.FONT_HERSHEY_SIMPLEX 
        text=f'Start: ({start_x}, {start_y}), End: ({end_x}, {end_y})'
        cv2.putText(img,text,(10 ,30),font ,1 ,(255 ,255 ,255), 3)

image_path='image.jpg'
img=cv2.imread(image_path)

desired_width=1680 
desired_height=1000 
img=cv2.resize(img,(desired_width ,desired_height))

cv2.namedWindow('Everest Image')
cv2.setMouseCallback('Everest Image',draw_rectangle)
    
while True:
    if not drawing:  
       # Show the image only when not drawing to prevent flickering.
       cv2.imshow('Everest Image',img)  
       
    if (cv2.waitKey(20) & 0xFF)==27: # Press 'Esc' key to exit.
       break

cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Global variables to store mouse click coordinates
start_x, start_y, end_x, end_y = -1, -1, -1, -1
drawing = False

# Mouse callback function
def draw_rectangle(event, x, y, flags, param):
    global start_x, start_y, end_x, end_y, drawing, img

    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        start_x, start_y = x, y
        end_x, end_y = x, y

    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing:
            end_x, end_y = x, y

    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        end_x, end_y = x, y

        # Draw a filled rectangle with transparent red at the dragged location
        color = (0, 0, 255, 128)  # Red with 50% transparency (BGR with alpha)
        thickness = -1  # Negative thickness fills the rectangle
        overlay = img.copy()
        cv2.rectangle(overlay, (start_x, start_y), (end_x, end_y), color, thickness)
        cv2.addWeighted(overlay, 0.5, img, 0.5, 0, img)

        # Display coordinates
        font = cv2.FONT_HERSHEY_SIMPLEX
        text = f'Start: ({start_x}, {start_y}), End: ({end_x}, {end_y})'
        cv2.putText(img, text, (10, 30), font, 1, (255, 255, 255), 2)

# Load the image (replace 'abab.jpg' with your image file path)
image_path = 'image.jpg'
img = cv2.imread(image_path)

# Resize the image to the desired dimensions (1680 x 1000)
desired_width = 1680
desired_height = 1000
img = cv2.resize(img, (desired_width, desired_height))

# Create a window and bind the function to the window
cv2.namedWindow('Everest Image')
cv2.setMouseCallback('Everest Image', draw_rectangle)
    
while True:
    cv2.imshow('Everest Image', img)
    if cv2.waitKey(20) & 0xFF == 27:  # Press 'Esc' key to exit
        break

cv2.destroyAllWindows()
